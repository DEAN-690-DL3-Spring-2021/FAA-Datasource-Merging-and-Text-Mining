# %%
import pandas as pd
import numpy as np
aid_data = pd.read_csv('a2019.csv',encoding='UTF-8',skipinitialspace=True)
aid_data1 = aid_data
sdr_data = pd.read_csv('sdr(2019_Occurred_Incidents).csv',encoding='UTF-8',skipinitialspace=True,dtype=str)
sdr_data1 = sdr_data
merged_aid_sdr = aid_data1.append(sdr_data1,sort=False)
merged_aid_sdr
# Out:
#                     c5   c1   c2  c3  ...  c660  eof  Unnamed: 86  Unnamed: 87
# 0      20191013023229A    A   91 NaN  ...   NaN  NaN          NaN          NaN
# 1      20191122023189A    A   91 NaN  ...   NaN  NaN          NaN          NaN
# 2      20191125023199I    I   91 NaN  ...   NaN  NaN          NaN          NaN
# 3      20191217023209A    A   91 NaN  ...   NaN  NaN          NaN          NaN
# 4      20191218023219I    I   91 NaN  ...   NaN  NaN          NaN          NaN
# ...                ...  ...  ...  ..  ...   ...  ...          ...          ...
# 61007              NaN  NaN  NaN NaN  ...   NaN  NaN          NaN          NaN
# 61008              NaN  NaN  NaN NaN  ...   NaN  NaN          NaN          NaN
# 61009              NaN  NaN  NaN NaN  ...   NaN  NaN          NaN          NaN
# 61010              NaN  NaN  NaN NaN  ...   NaN  NaN          NaN          NaN
# 61011              NaN  NaN  NaN NaN  ...   NaN  NaN          NaN          NaN
#
# [63403 rows x 243 columns]

# %%
eon_data = pd.read_csv('EON-2019(Jan-Mar).csv',encoding='UTF-8',skipinitialspace=True)
eon_data1 = eon_data
merged_total = merged_aid_sdr.append(eon_data1,sort=False)
merged_total
# Out:
#                    c5   c1   c2  ...  Unnamed: 33  Unnamed: 34  Unnamed: 35
# 0     20191013023229A    A   91  ...          NaN          NaN          NaN
# 1     20191122023189A    A   91  ...          NaN          NaN          NaN
# 2     20191125023199I    I   91  ...          NaN          NaN          NaN
# 3     20191217023209A    A   91  ...          NaN          NaN          NaN
# 4     20191218023219I    I   91  ...          NaN          NaN          NaN
# ...               ...  ...  ...  ...          ...          ...          ...
# 9718              NaN  NaN  NaN  ...          47Z          NaN          NaN
# 9719              NaN  NaN  NaN  ...          NaN          NaN          NaN
# 9720              NaN  NaN  NaN  ...          NaN          NaN          NaN
# 9721              NaN  NaN  NaN  ...          NaN          NaN          NaN
# 9722              NaN  NaN  NaN  ...          NaN          NaN          NaN
#
# [73126 rows x 279 columns]

# %%
merged_total.reset_index(drop=True,inplace=True)
